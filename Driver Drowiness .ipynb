# %% [markdown]
# Installing Some Libraries : -

# %%
# !pip uninstall torch torchvision
# Out:
# ^C

# %%
# !pip install torch torchvision torchaudio
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install torch torchvision --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install torch --upgrade
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from matplotlib import pyplot as plt 
import numpy as np
import cv2

# %% [markdown]
# ### Installing Dependicies :-

# %%
# !pip install ultralytics
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %% [markdown]
# ### Loading Model : -

# %%
# Loading Pre-trained ultralytics from torch hub -
model = torch.hub.load("ultralytics/yolov5","yolov5s")
# Out:
# Using cache found in C:\Users\rinke/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-12-13 Python-3.11.4 torch-2.1.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# ### Make Detections : -

# %%
img = 'https://images.livemint.com/img/2022/10/27/1600x900/Delhi-traffic_1666840159280_1666840159716_1666840159716.jpg'
# img = "https://th-i.thgim.com/public/opinion/editorial/r055a0/article29789711.ece/alternates/FREE_1200/TH25-PARLEY-PRAYER1"

# %%
result = model(img)
result.print()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 result = model(img)
#       2 result.print()
#
# File c:\Users\rinke\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\rinke\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.imshow(np.squeeze(results.render()))
#       3 plt.show()
#
# NameError: name 'results' is not defined

# %%
# For zooming 
results.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # For zooming
# ----> 2 results.show()
#
# NameError: name 'results' is not defined

# %%
# We can also Real Time Detect it by changing the video capture to the path : -
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret , frame = cap.read()
    
    # make Detections
    results = model(frame)

    cv2.imshow("Driver Drowiness System", np.squeeze(results.render()))

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[32], line 7
#       4 ret , frame = cap.read()
#       6 # make Detections
# ----> 7 results = model(frame)
#       9 cv2.imshow("Driver Drowiness System", np.squeeze(results.render()))
#      11 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# File c:\Users\rinke\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\rinke\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
# ...

# %% [markdown]
# ### Training the model :

# %%
import uuid # its a identifier
import os
import time

# %%
IMAGES_PATH = os.path.join("data","images")
labels = ['awake','drowsy']
number_imgs = 20

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
! git clone https://github.com/HumanSignal/labelImg.git
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# Installing some dependies for labelling our images :
! pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt

# %% [markdown]
# ### Loading Model-

# %%
model = torch.hub.load("ultralytics/yolov5",'custom',path = "yolov5/runs/train/exp3/weights/last.pt", force_reload = True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\rinke/.cache\torch\hub\master.zip
# YOLOv5  2023-12-15 Python-3.11.4 torch-2.1.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data',"images","awake.f29a3543-99f7-11ee-a331-ec2e98cbde0e.jpg")

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 Awake
# Speed: 126.5ms pre-process, 423.0ms inference, 25.4ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# Using matplotlib backend: QtAgg

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %% [markdown]
# # Making real time detection

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('Driver Detetion Sysetem', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
